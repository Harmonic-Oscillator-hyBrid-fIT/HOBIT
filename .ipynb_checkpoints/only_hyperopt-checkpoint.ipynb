# %% [markdown]
# # Trigonometric fit using hyperopt
#
# https://github.com/fmfn/BayesianOptimization<br>
# https://github.com/hyperopt/hyperopt

# %%
import numpy as np
import sklearn
from matplotlib import pyplot as plt 
from sklearn.metrics import mean_squared_error, r2_score
from hyperopt import hp, tpe, Trials, fmin
import time

# %%
np.random.seed(12345)

n = 500
x_data = np.linspace(-5, 5, num= n)
y_data = 30+ 5 * np.cos(5 * x_data + 2) + 1.5*np.random.normal(size= n)
plt.scatter(x_data, y_data)

# %%
# random split the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# %%
def objective(a0,a1, w, f):
    """Objective function to minimize"""
    return np.mean((a0+ a1 * np.cos(w*X_train + f) - y_train)**2)

# %%
def objective2(args):
    return objective(*args)

# %% [markdown]
# ## hyperopt

# %%
space = [hp.uniform('a0', 25, 35),
         hp.uniform('a1', 0, 10), 
         hp.uniform('w', 0, 10), 
         hp.uniform('f', -np.pi, np.pi)]

tpe_algo = tpe.suggest
tpe_trials = Trials()

start = time.time()
tpe_best = fmin(fn=objective2, space=space, algo=tpe_algo, trials=tpe_trials, max_evals= 500)
end = time.time()
print('Time:', end - start)

print(tpe_best)
# Out:
# 100%|███████████████████████████████████████████████| 500/500 [00:17<00:00, 28.76trial/s, best loss: 6.980312670191794]
# Time: 17.4323787689209
# {'a0': 28.728075875427614, 'a1': 5.69164311997959, 'f': 1.5537784212413999, 'w': 4.950159594240259}

# %%
# Test
from sklearn.metrics import mean_squared_error, r2_score

ypred = tpe_best['a0']+ tpe_best['a1'] * np.cos(tpe_best['w'] * X_test + tpe_best['f'])

rmse = np.sqrt(mean_squared_error(y_test,ypred))
r2 = r2_score(y_test,ypred)
print('rmse:', rmse)
print('r2:',r2)
# Out:
# rmse: 2.8535530579405233
# r2: 0.42175455648392246

# %%
y = tpe_best['a0'] + tpe_best['a1'] * np.cos(tpe_best['w'] * x_data + tpe_best['f'])

fig, ax = plt.subplots()
ax.scatter(x_data, y_data, label= 'observations', color= '#678491', s= 5)
ax.plot(x_data, y, label= 'predictions', color= '#EA1B1D')
ax.set_ylabel('y', fontsize= 14)
ax.set_xlabel('X', fontsize= 14)
ax.set_title('Fit using hyperopt vs. Original data', fontsize= 14);
